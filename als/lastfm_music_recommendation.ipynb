# %% [markdown]
# Author: Youssef Belyazid <br>
# Email: belyazidyous@gmail.com <br>
# Year: 2021

# %% [markdown]
# ### Loading lastfm Dataset

# %%
dbutils.fs.mv("dbfs:/FileStore/tables/data_lastfm/data_lastfm.zip","file:/databricks/driver/data_lastfm.zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: True</div>

# %%
# %%bash
# unzip data_lastfm.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  data_lastfm.zip
#   inflating: data_lastfm.csv
# </div>

# %%
dbutils.fs.mv("file:/databricks/driver/data_lastfm.csv", "dbfs:/FileStore/tables/data_lastfm.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: True</div>

# %%
from pyspark.sql.functions import col, explode, sum, count, expr
from pyspark.ml.feature import StringIndexer, IndexToString
from pyspark.ml import Transformer
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark import keyword_only
from pyspark.ml.evaluation import Evaluator
from pyspark.ml.param.shared import Param
from pyspark.mllib.evaluation import RankingMetrics
from pyspark.sql import Window
import pyspark.sql.functions as F
from pyspark.ml.recommendation import ALS, ALSModel
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Reading and preprocessing the data

# %%
lastfm_df = spark.read.format("csv").option("inferSchema", "true").option("header","true").\
load("dbfs:/FileStore/tables/data_lastfm.csv").\
withColumn('play_count', col('play_count').cast('integer'))

lastfm_df.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[user_sha1: string, artist_name: string, play_count: int]</div>

# %%
class clean_data(Transformer):
  
    def _transform(self, df):
      clean_df = df.dropna()
      return clean_df
      

class preprocess_data(Transformer):
  
  @keyword_only
  def __init__(self,cutoff_items=5, cutoff_users=750):
      super(preprocess_data, self).__init__()
      self.cutoff_items = cutoff_items
      self.cutoff_users = cutoff_users

  def _transform(self, df):
    df1 = df \
            .groupBy('user_sha1') \
            .agg(count('artist_name').alias('artist_name_count')) \
            .where(f'artist_name_count >= {self.cutoff_items}') \
            .select('user_sha1')

    df1 = df.join(df1, 'user_sha1', 'inner')

    df2 = df1 \
            .groupBy('artist_name') \
            .agg(count('user_sha1').alias('user_count')) \
            .where(f'user_count >= {self.cutoff_users}') \
            .select('artist_name')

    preprocessed_data = df.join(df2, 'artist_name', 'inner')

    return preprocessed_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
clean_data = clean_data()
lastfm_df = clean_data.transform(lastfm_df)

preprocess_data = preprocess_data()
lastfm_df = preprocess_data.transform(lastfm_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(lastfm_df.take(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>artist_name</th><th>user_sha1</th><th>play_count</th></tr></thead><tbody><tr><td>1349</td><td>0039f6a10a8afc639e621ec4a6601306bafd9adf</td><td>4</td></tr><tr><td>1349</td><td>008c354e33658fb3b68de133ec99e7d57f191bb0</td><td>190</td></tr><tr><td>1349</td><td>00b647282eee5f49a1f811f45c55f8878dae8383</td><td>120</td></tr><tr><td>1349</td><td>00ec5fa841a608ce9c1280771cd95b48466dd6d0</td><td>68</td></tr><tr><td>1349</td><td>012876befe9c49325fdd8e10f00f94b920b174c6</td><td>19</td></tr></tbody></table></div>

# %% [markdown]
# ### Exploring the data

# %%
def get_sparsity(df, col_users, col_items, rating):
  num_users = df.select(col_users).distinct().count()
  num_artists = df.select(col_items).distinct().count()
  num_ratings = df.select(rating).count()
  sparsity = round((1 - (num_ratings)/(num_users*num_artists))*100,3)
  return sparsity
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sparsity_rate = get_sparsity(lastfm_df, 'user_sha1', 'artist_name', 'play_count')
print(f'the data sparsity rate is:{sparsity_rate}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">the data sparsity rate is:99.093
# </div>

# %%
# top 5 most played artists
display(lastfm_df.groupby('artist_name').agg(sum('play_count').alias("sum_play_count"))\
        .sort("sum_play_count", ascending=False).take(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>artist_name</th><th>sum_play_count</th></tr></thead><tbody><tr><td>the beatles</td><td>30466827</td></tr><tr><td>radiohead</td><td>27426234</td></tr><tr><td>coldplay</td><td>16686772</td></tr><tr><td>pink floyd</td><td>15943557</td></tr><tr><td>metallica</td><td>15481852</td></tr></tbody></table></div>

# %% [markdown]
# ### Training ALS

# %%
#converting user_sha1 and artist_name to integer indexes to fit als requirements

indexer_user_id = StringIndexer(inputCol="user_sha1", outputCol="user_id",handleInvalid="skip")
lastfm_indexed = indexer_user_id.fit(lastfm_df).transform(lastfm_df).\
withColumn('user_id', col('user_id').cast('integer'))

indexer_artist_id = StringIndexer(inputCol="artist_name", outputCol="artist_id",handleInvalid="skip")
index_artist_id_model = indexer_artist_id.fit(lastfm_indexed) 
lastfm_indexed = index_artist_id_model.transform(lastfm_indexed).\
withColumn('artist_id', col('artist_id').cast('integer'))

lastfm_indexed = lastfm_indexed.select('user_id', 'artist_id', 'play_count')

display(lastfm_indexed.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>artist_id</th><th>play_count</th></tr></thead><tbody><tr><td>76877</td><td>2506</td><td>4</td></tr><tr><td>120115</td><td>2506</td><td>190</td></tr><tr><td>31011</td><td>2506</td><td>120</td></tr><tr><td>269515</td><td>2506</td><td>68</td></tr><tr><td>312995</td><td>2506</td><td>19</td></tr></tbody></table></div>

# %%
# model hyperparameters fine-tuning using cross-validation
als = ALS(userCol="user_id",
          itemCol="artist_id",
          ratingCol="play_count",
          nonnegative = True,
          implicitPrefs = True,
          coldStartStrategy="drop",
          checkpointInterval=1)

rankingEvaluator = RankingEvaluator()

param_grid = ParamGridBuilder()\
            .addGrid(als.rank, [5,10,20])\
            .addGrid(als.alpha,[1,10,40,60])\
            .addGrid(als.regParam, [.01, .1, 1, 10,100]) \
            .addGrid(als.maxIter, [10, 12, 15])\
            .build()

cv = CrossValidator(estimator=als,
                    estimatorParamMaps=param_grid ,
                    evaluator=rankingEvaluator,
                    numFolds=5)

cvModel = cv.fit(lastfm_indexed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:838: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
(train, test) = lastfm_indexed.randomSplit([0.8, 0.2], seed = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# model with the best hyper-paramters combination

als = ALS(userCol="user_id",
          itemCol="artist_id",
          ratingCol="play_count",
          nonnegative = False,
          implicitPrefs = True,
          coldStartStrategy="drop",
         alpha=40)
model = als.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#saving the model
def save_model(model, path):
  model.save(path)
  
def load_model(path):
  model = ALSModel.load(path)
  return model

save_model(model, 'dbfs:/FileStore/als_model')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#utility function for evaluating the model

class RankingEvaluator(Evaluator):

    @keyword_only
    def __init__(self, k=10):
        super(RankingEvaluator, self).__init__()
        self.k = k

    def _evaluate(self, predictedDF):
      
        windowSpec = Window.partitionBy('user_id').orderBy(col('prediction').desc())
        perUserPredictedItemsDF = predictedDF \
            .select('user_id', 'artist_id', 'prediction', F.rank().over(windowSpec).alias('rank')) \
            .where('rank <= {0}'.format(self.k)) \
            .groupBy('user_id') \
            .agg(expr('collect_list(artist_id) as items'))

        windowSpec = Window.partitionBy('user_id').orderBy(col('play_count').desc())
        perUserActualItemsDF = predictedDF \
            .select('user_id', 'artist_id', 'play_count', F.rank().over(windowSpec).alias('rank')) \
            .where('rank <= {0}'.format(self.k)) \
            .groupBy('user_id') \
            .agg(expr('collect_list(artist_id) as items'))

        perUserItemsRDD = perUserPredictedItemsDF.join(F.broadcast(perUserActualItemsDF), 'user_id', 'inner') \
            .rdd \
            .map(lambda row: (row[1], row[2]))

        if perUserItemsRDD.isEmpty():
            return 0.0

        rankingMetrics = RankingMetrics(perUserItemsRDD)
        metric = rankingMetrics.meanAveragePrecisionAt(self.k)
        return metric
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#evaluating the model on the test set 

predictions_df = model.transform(test)
re = RankingEvaluator()
re.evaluate(predictions_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 0.970095845272082</div>

# %% [markdown]
# ### Saving a dataframe with user_id, actual artists listened to, and recommended artists

# %%
# generating a recommendation of 10 artists for each user
rec = model.recommendForAllUsers(10)\
.selectExpr("user_id", "explode(recommendations) as recom")\
.select("user_id", "recom.artist_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# converting artist_id back to artist_name and grouping them in a list
labelReverse = IndexToString(inputCol="artist_id", outputCol='artist_name', labels = index_artist_id_model.labels)
rec_transformed = labelReverse.transform(rec)
final_rec = rec_transformed.groupBy('user_id').\
agg(expr("collect_list(artist_name) as artists"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# joining the dataframe with artists recommended and artists actually listned to on user_id
predvsactual = labelReverse.transform(train).\
orderBy(col("user_id"), expr("play_count DESC")).groupBy('user_id').\
agg(expr("collect_list(artist_name) as artists_actual")).join(final_rec, ["user_id"]).rdd\
.map(lambda row: (row[0],row[1][:10],row[2]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# exporting the previous dataframe via pickle
predvsactual_df = predvsactual.toDF().toPandas().rename(columns={"_1": "user_id", "_2": "Listened to", "_3":"Recommendations"})
predvsactual_df.to_pickle('recommendations-artists.pkl',protocol=4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predvsactual_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>Listened to</th>
#       <th>Recommendations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31</td>
#       <td>[daft punk, café del mar, leonard cohen, röyks...</td>
#       <td>[wir sind helden, schiller, sasha, acda en de ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34</td>
#       <td>[grizzly bear, arvo pärt, digitalism, neutral ...</td>
#       <td>[alina orlova, sopor aeternus &amp; the ensemble o...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>53</td>
#       <td>[mogwai, hadouken!, the presets, elliott smith...</td>
#       <td>[canned heat, emir kusturica &amp; the no smoking ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>65</td>
#       <td>[sum 41, hoobastank, the offspring, nirvana, a...</td>
#       <td>[bad company, frank klepacki, kotoko, raappana...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>78</td>
#       <td>[3 doors down, the strokes, r.e.m., peaches, +...</td>
#       <td>[angerfist, drive-by truckers, black lips, the...</td>
#     </tr>
#   </tbody>
# </table>
# </div>
